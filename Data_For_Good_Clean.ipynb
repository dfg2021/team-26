# %%
#Jacob Rasey
#Data Analysis

# %%
#importing necessary packages
import pandas as pd
import numpy as np
import missingno as msno
from matplotlib import pyplot as plt
import seaborn as sns

# %%
#cleaning the data
data = pd.read_excel(r'.\\Goal13.xlsx')

clean = pd.DataFrame(data, columns=['SeriesCode', 'SeriesDescription', 'GeoAreaName', 'Value', 'Time_Detail'])

emdata = clean.groupby(["SeriesCode"]).get_group('EN_ATM_GHGT_NAIP')
anemdata = clean.groupby(["SeriesCode"]).get_group('EN_ATM_GHGT_AIP').sort_values(by=['GeoAreaName'], ascending='False')

# %%
#viewing the data
emdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 576 entries, 11825 to 12400
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SeriesCode         576 non-null    object
#  1   SeriesDescription  576 non-null    object
#  2   GeoAreaName        576 non-null    object
#  3   Value              576 non-null    float64
#  4   Time_Detail        576 non-null    object
# dtypes: float64(1), object(4)
# memory usage: 27.0+ KB

# %%
anemdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 860 entries, 10965 to 11785
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SeriesCode         860 non-null    object
#  1   SeriesDescription  860 non-null    object
#  2   GeoAreaName        860 non-null    object
#  3   Value              860 non-null    float64
#  4   Time_Detail        860 non-null    object
# dtypes: float64(1), object(4)
# memory usage: 40.3+ KB

# %%
#checking missing values
msno.matrix(emdata)
# Out:
# <AxesSubplot:>

# %%
sns.barplot(data = emdata, x = "GeoAreaName", y = "Value")
# Out:
# <AxesSubplot:xlabel='GeoAreaName', ylabel='Value'>

# %%
sns.barplot(data = emdata, x = "Time_Detail", y = "Value")
# Out:
# <AxesSubplot:xlabel='Time_Detail', ylabel='Value'>

# %%
sns.barplot(data = anemdata, x = "Time_Detail", y = "Value")
# Out:
# <AxesSubplot:xlabel='Time_Detail', ylabel='Value'>

# %%
emdata["GeoAreaName"].value_counts()
# Out:
# Kazakhstan            19
# Dominica              18
# Republic of Korea     17
# Brazil                17
# Israel                17
#                       ..
# Bahamas                1
# El Salvador            1
# Brunei Darussalam      1
# State of Palestine     1
# Panama                 1
# Name: GeoAreaName, Length: 136, dtype: int64

# %%
#Writing the clean data to a csv file for tableau visualization
emdata.to_csv("C:/Summer_2021/JPMorgan_Hackathon/emdata.csv")

# %%
#writing the other clean data to a csv file
anemdata.to_csv("C:/Summer_2021/JPMorgan_Hackathon/anemdata.csv")

# %%
#Is american not inlcuded for greenhouse gas emissions?
emdata[["GeoAreaName"]].value_counts()
#answer: no
# Out:
# GeoAreaName
# Kazakhstan                          19
# Dominica                            18
# Israel                              17
# Republic of Korea                   17
# Brazil                              17
#                                     ..
# Panama                               1
# Papua New Guinea                     1
# Congo                                1
# Comoros                              1
# Lao People's Democratic Republic     1
# Length: 136, dtype: int64
